# %%
import os
import csv
import requests
import base64
import re
import Levenshtein

# %%
# === KONFIGURASI ===
image_dir = "test"
label_csv = "label.csv"
output_csv = "results.csv"
lmstudio_url = "http://localhost:1234/v1/chat/completions"
model_name = "llava-llama-3-8b-v1_1"
# model_name = "bakllava1-1.5-mistral-7b"

# %%
# === LOAD LABEL MANUAL ===
def load_labels(label_file):
    label_map = {}
    with open(label_file, newline="") as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            fname = row["image"].strip()
            gt = row["ground_truth"].strip().upper()
            label_map[fname] = re.sub(r'[^A-Z0-9]', '', gt)  # Bersihkan GT
    return label_map

# %%
# === ENCODE IMAGE BASE64 ===
def encode_image(image_path):
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode('utf-8')

# %%
# === HITUNG CER ===
def cer_score(gt, pred):
    if len(gt) == 0:
        return 1.0
    distance = Levenshtein.distance(gt, pred)
    return round(distance / len(gt), 3)

# %%
# === INFER KE LM STUDIO ===
def ocr_infer(base64_image):
    headers = {"Content-Type": "application/json"}
    prompt = (
    "You are a specialized OCR model for Indonesian vehicle license plates.\n"
    "ONLY return the license plate number as a single string, with no extra explanation or punctuation.\n"
    "The format may include letters and numbers (e.g., B1234XYZ, D 123 AB, AB1234CD).\n"
    "Respond with only the plate number. Do NOT include any commentary, description, or full sentences."

    )
    payload = {
        "model": model_name,
        "messages": [
            {"role": "system", "content": prompt},
            {
                "role": "user",
                "content": [
                    {
                        "type": "image_url",
                        "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}
                    },
                    {
                        "type": "text",
                        "text": "What is the license plate number in this image? Only respond with the number."
                    }
                ]
            }
        ],
        "temperature": 0,
        "max_tokens": 30
    }
    try:
        response = requests.post(lmstudio_url, headers=headers, json=payload)
        response.raise_for_status()
        result = response.json()
        return result['choices'][0]['message']['content'].strip()
    except Exception as e:
        return f"ERROR: {e}"

# %%
# === FILTER DENGAN REGEX ===
def extract_plate(text):
    text = text.upper()
    match = re.search(r"[A-Z]{1,2}[0-9]{1,4}[A-Z]{0,3}", text)
    return match.group(0) if match else re.sub(r'[^A-Z0-9]', '', text)

# %%
# === MAIN ===
def main():
    label_map = load_labels(label_csv)
    total_cer = 0
    total_images = 0

    with open(output_csv, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["image", "ground_truth", "prediction", "CER_score"])

        for filename in sorted(os.listdir(image_dir)):
            if filename.lower().endswith((".jpg", ".jpeg", ".png")):
                img_path = os.path.join(image_dir, filename)
                gt = label_map.get(filename, "").upper()

                if not gt:
                    print(f"⚠️ Ground truth tidak ditemukan: {filename}")
                    continue

                try:
                    b64_img = encode_image(img_path)
                    raw_pred = ocr_infer(b64_img)

                    if raw_pred.startswith("ERROR"):
                        cleaned_pred = "ERROR"
                        cer = 1.0
                    else:
                        cleaned_pred = extract_plate(raw_pred)
                        cer = cer_score(gt, cleaned_pred)

                    total_cer += cer
                    total_images += 1

                    print(f"🔍 {filename}")
                    print(f"   ✅ Prediksi: {cleaned_pred} | GT: {gt} | CER: {cer}\n")
                    writer.writerow([filename, gt, cleaned_pred, cer])

                except Exception as e:
                    print(f"❌ {filename} → UNHANDLED ERROR: {e}")
                    writer.writerow([filename, gt, "UNHANDLED ERROR", 1.0])
                    total_cer += 1.0
                    total_images += 1

    avg_cer = round(total_cer / total_images, 3) if total_images else 1.0
    print(f"\n📊 Rata-rata CER dari {total_images} gambar: {avg_cer}")

if __name__ == "__main__":
    main()
# Out:
# 🔍 test001_1.jpg
#    ✅ Prediksi: S140 | GT: B9140BCD | CER: 0.625
#
# 🔍 test001_2.jpg
#    ✅ Prediksi: B2407UZO | GT: B2407UZO | CER: 0.0
#
# 🔍 test001_3.jpg
#    ✅ Prediksi: B2842PKM | GT: B2642PKM | CER: 0.125
#
# 🔍 test002_1.jpg
#    ✅ Prediksi: BG1352AE | GT: BG1352AE | CER: 0.0
#
# 🔍 test003_1.jpg
#    ✅ Prediksi: B2634UZF | GT: B2634UZF | CER: 0.0
#
# 🔍 test003_2.jpg
#    ✅ Prediksi: B1995JVK | GT: B1995JVK | CER: 0.0
#
# 🔍 test004_1.jpg
#    ✅ Prediksi: B9062VEH | GT: B9062VEH | CER: 0.0
#
# 🔍 test005_1.jpg
#    ✅ Prediksi: DD798KM | GT: DD3798KM | CER: 0.125
#
# 🔍 test006_1.jpg
#    ✅ Prediksi: T1329KC | GT: T1329KC | CER: 0.0
#
# 🔍 test007_1.jpg
#    ✅ Prediksi: AD8865EE | GT: AD8865EE | CER: 0.0
#
# 🔍 test008_1.jpg
#    ✅ Prediksi: DK1157AAB | GT: DK1157AAB | CER: 0.0
#
# 🔍 test008_2.jpg
#    ✅ Prediksi: AA1997FE | GT: AA1997FE | CER: 0.0
#
# 🔍 test009_1.jpg
#    ✅ Prediksi: H8518NA | GT: H8518NA | CER: 0.0
#
# 🔍 test009_2.jpg
#    ✅ Prediksi: K1649GB | GT: K1649GB | CER: 0.0
#
# 🔍 test010_1.jpg
#    ✅ Prediksi: B9416PCN | GT: B9416PCN | CER: 0.0
#
# 🔍 test010_2.jpg
#    ✅ Prediksi: H1147UY | GT: H1147UY | CER: 0.0
#
# 🔍 test011_1.jpg
#    ✅ Prediksi: H1691IL | GT: H1691IL | CER: 0.0
#
# 🔍 test011_2.jpg
#    ✅ Prediksi: B9374RI | GT: B9374RI | CER: 0.0
#
# 🔍 test011_3.jpg
#    ✅ Prediksi: D1204AIG | GT: D1204AIG | CER: 0.0
#
# 🔍 test012_1.jpg
#    ✅ Prediksi: E1887BA | GT: E1887BA | CER: 0.0
#
# 🔍 test013_1.jpg
#    ✅ Prediksi: B1439UZP | GT: B1439UZP | CER: 0.0
#
# 🔍 test013_2.jpg
#    ✅ Prediksi: B1128W | GT: B1128W0S | CER: 0.25
#
# 🔍 test014_1.jpg
#    ✅ Prediksi: B1388DFX | GT: B1388DFX | CER: 0.0
#
# 🔍 test015_1.jpg
#    ✅ Prediksi: AD1798BT | GT: AD1898BT | CER: 0.125
#
# 🔍 test016_1.jpg
#    ✅ Prediksi: E1517D | GT: E1517DQ | CER: 0.143
#
# 🔍 test017_1.jpg
#    ✅ Prediksi: AD8982FS | GT: AD8982FS | CER: 0.0
#
# 🔍 test018_1.jpg
#    ✅ Prediksi: L7603UA | GT: L7603UA | CER: 0.0
#
# 🔍 test019_1.jpg
#    ✅ Prediksi: AD7HS | GT: AD7HS | CER: 0.0
#
# 🔍 test019_2.jpg
#    ✅ Prediksi: B1959WYK | GT: B1959WYK | CER: 0.0
#
# 🔍 test020_1.jpg
#    ✅ Prediksi: AG8634EK | GT: AG8634EK | CER: 0.0
#
# 🔍 test020_2.jpg
#    ✅ Prediksi: AD1328PY | GT: AD1329PY | CER: 0.125
#
# 🔍 test021_1.jpg
#    ✅ Prediksi: BA1709DW | GT: BA1709DW | CER: 0.0
#
# 🔍 test021_2.jpg
#    ✅ Prediksi: W1236VZ | GT: W1236VZ | CER: 0.0
#
# 🔍 test022_1.jpg
#    ✅ Prediksi: W1825 | GT: W1825OZ | CER: 0.286
#
# 🔍 test022_2.jpg
#    ✅ Prediksi: L1202UE | GT: L1202UE | CER: 0.0
#
# 🔍 test022_3.jpg
#    ✅ Prediksi: L3823 | GT: L3823IB | CER: 0.286
#
# 🔍 test023_1.jpg
#    ✅ Prediksi: B1730JLO | GT: B1730JLO | CER: 0.0
#
# 🔍 test024_1.jpg
#    ✅ Prediksi: B2964TRU | GT: B2964TRU | CER: 0.0
#
# 🔍 test025_1.jpg
#    ✅ Prediksi: S5585LP | GT: S5585LP | CER: 0.0
#
# 🔍 test025_2.jpg
#    ✅ Prediksi: L2858RR | GT: L2858RR | CER: 0.0
#
# 🔍 test025_3.jpg
#    ✅ Prediksi: W1185Z | GT: W1185ZO | CER: 0.143
#
# 🔍 test025_4.jpg
#    ✅ Prediksi: 9820YU | GT: 9840VU | CER: 0.333
#
# 🔍 test026_1.jpg
#    ✅ Prediksi: N9652DE | GT: N9652DF | CER: 0.143
#
# 🔍 test026_2.jpg
#    ✅ Prediksi: L3836ZX | GT: L3836ZX | CER: 0.0
#
# 🔍 test027_1.jpg
#    ✅ Prediksi: N1905IG | GT: N1905IG | CER: 0.0
#
# 🔍 test027_2.jpg
#    ✅ Prediksi: B1109CLR | GT: B1109CLR | CER: 0.0
#
# 🔍 test027_3.jpg
#    ✅ Prediksi: L1840AA | GT: L1840AA | CER: 0.0
#
# 🔍 test028_1.jpg
#    ✅ Prediksi: E0143 | GT: L1438EO | CER: 0.714
#
# 🔍 test028_2.jpg
#    ✅ Prediksi: L1436AA | GT: 1436AAA | CER: 0.286
#
# 🔍 test029_1.jpg
#    ✅ Prediksi: W1516 | GT: W1518WF | CER: 0.429
#
# 🔍 test029_2.jpg
#    ✅ Prediksi: G1986N | GT: G1986N | CER: 0.0
#
# 🔍 test029_3.jpg
#    ✅ Prediksi: L1588 | GT: L1588OO | CER: 0.286
#
# 🔍 test029_4.jpg
#    ✅ Prediksi: L1436AAA | GT: L1436AAA | CER: 0.0
#
# 🔍 test030_1.jpg
#    ✅ Prediksi: S8062NF | GT: S8062NF | CER: 0.0
#
# 🔍 test030_2.jpg
#    ✅ Prediksi: G1894TE | GT: G1894TE | CER: 0.0
#
# 🔍 test031_1.jpg
#    ✅ Prediksi: L1560JQ | GT: L1560JQ | CER: 0.0
#
# 🔍 test031_2.jpg
#    ✅ Prediksi: L1568 | GT: L1568Q0 | CER: 0.286
#
# 🔍 test031_3.jpg
#    ✅ Prediksi: L1932AAZ | GT: L1932AAZ | CER: 0.0
#
# 🔍 test032_1.jpg
#    ✅ Prediksi: B2754SKY | GT: B2754SKY | CER: 0.0
#
# 🔍 test032_2.jpg
#    ✅ Prediksi: W1192K | GT: W1192K | CER: 0.0
#
# 🔍 test033_1.jpg
#    ✅ Prediksi: L4561VK | GT: L4561VK | CER: 0.0
#
# 🔍 test033_2.jpg
#    ✅ Prediksi: L2693CA | GT: L2693GA | CER: 0.143
#
# 🔍 test033_3.jpg
#    ✅ Prediksi: 0827G | GT: W9847G | CER: 0.5
#
# 🔍 test033_4.jpg
#    ✅ Prediksi: 1762ABJ | GT: L1762ABJ | CER: 0.125
#
# 🔍 test034_1.jpg
#    ✅ Prediksi: L1811SU | GT: L1811SU | CER: 0.0
#
# 🔍 test034_2.jpg
#    ✅ Prediksi: W1167V | GT: W1167V0 | CER: 0.143
#
# 🔍 test034_3.jpg
#    ✅ Prediksi: S6131ACE | GT: S61310CF | CER: 0.25
#
# 🔍 test034_4.jpg
#    ✅ Prediksi: L2570AAD | GT: L2570AAD | CER: 0.0
#
# 🔍 test035_1.jpg
#    ✅ Prediksi: L9643NN | GT: L9643NN | CER: 0.0
#
# 🔍 test035_2.jpg
#    ✅ Prediksi: 5247CI | GT: L5247GI | CER: 0.286
#
# 🔍 test035_3.jpg
#    ✅ Prediksi: L2498AAM | GT: L2498AAM | CER: 0.0
#
# 🔍 test035_4.jpg
#    ✅ Prediksi: W1696YO | GT: W1696YO | CER: 0.0
#
# 🔍 test036_1.jpg
#    ✅ Prediksi: B1231JJA | GT: B1231JJA | CER: 0.0
#
# 🔍 test036_2.jpg
#    ✅ Prediksi: B1618UAE | GT: B1618UAE | CER: 0.0
#
# 🔍 test037_1.jpg
#    ✅ Prediksi: L1775V | GT: L1775V0 | CER: 0.143
#
# 🔍 test037_2.jpg
#    ✅ Prediksi: L300RX | GT: L300RX | CER: 0.0
#
# 🔍 test037_3.jpg
#    ✅ Prediksi: L1879VC | GT: L1879VG | CER: 0.143
#
# 🔍 test038_1.jpg
#    ✅ Prediksi: D1523YCN | GT: D1523YCN | CER: 0.0
#
# 🔍 test038_2.jpg
#    ✅ Prediksi: L1877ACU | GT: L1877ACU | CER: 0.0
#
# 🔍 test039_1.jpg
#    ✅ Prediksi: L1069VK | GT: L1069VK | CER: 0.0
#
# 🔍 test040_1.jpg
#    ✅ Prediksi: S1595LL | GT: S1595LL | CER: 0.0
#
# 🔍 test041_1.jpg
#    ✅ Prediksi: B1231JJA | GT: B1231JJA | CER: 0.0
#
# 🔍 test042_1.jpg
#    ✅ Prediksi: AD1174SF | GT: AD1174SF | CER: 0.0
#
# 🔍 test043_1.jpg
#    ✅ Prediksi: W1898YW | GT: W1898YW | CER: 0.0
#
# 🔍 test043_2.jpg
#    ✅ Prediksi: W1470PG | GT: W1470PG | CER: 0.0
#
# 🔍 test044_1.jpg
#    ✅ Prediksi: L1930KF | GT: L1930KF | CER: 0.0
#
# 🔍 test044_2.jpg
#    ✅ Prediksi: N1004HE | GT: N1004HE | CER: 0.0
#
# 🔍 test045_1.jpg
#    ✅ Prediksi: 1347LJ | GT: S1347LJ | CER: 0.143
#
# 🔍 test046_1.jpg
#    ✅ Prediksi: L1470ABK | GT: L1470ABK | CER: 0.0
#
# 🔍 test046_2.jpg
#    ✅ Prediksi: L1265MX | GT: L1265MX | CER: 0.0
#
# 🔍 test047_1.jpg
#    ✅ Prediksi: 1524SY | GT: N1524SY | CER: 0.143
#
# 🔍 test047_2.jpg
#    ✅ Prediksi: L1678ACE | GT: L1678ACE | CER: 0.0
#
# 🔍 test048_1.jpg
#    ✅ Prediksi: L9316BC | GT: L9316BC | CER: 0.0
#
# 🔍 test048_2.jpg
#    ✅ Prediksi: W1838AY | GT: W1838AY | CER: 0.0
#
# 🔍 test049_1.jpg
#    ✅ Prediksi: N1376DE | GT: N1376DE | CER: 0.0
#
# 🔍 test049_2.jpg
#    ✅ Prediksi: N79AP | GT: N79AP | CER: 0.0
#
# 🔍 test050_1.jpg
#    ✅ Prediksi: L1265OF | GT: L1265OF | CER: 0.0
#
# 🔍 test050_2.jpg
#    ✅ Prediksi: N1095G | GT: N1095G | CER: 0.0
#
# 🔍 test051_1.jpg
#    ✅ Prediksi: N1718HC | GT: N1718HC | CER: 0.0
#
# 🔍 test052_1.jpg
#    ✅ Prediksi: N679 | GT: N6497KS | CER: 0.571
#
# 🔍 test052_2.jpg
#    ✅ Prediksi: N5235ABX | GT: N5235ABX | CER: 0.0
#
# 🔍 test052_3.jpg
#    ✅ Prediksi: N4980KJ | GT: N4980KJ | CER: 0.0
#
# 🔍 test053_1.jpg
#    ✅ Prediksi: N1365AA | GT: N1365AAO | CER: 0.125
#
# 🔍 test054_1.jpg
#    ✅ Prediksi: N1077AAK | GT: N1077AAK | CER: 0.0
#
# 🔍 test054_2.jpg
#    ✅ Prediksi: N1084AA | GT: N1084AAO | CER: 0.125
#
# 🔍 test055_1.jpg
#    ✅ Prediksi: N1610KS | GT: N1610KS | CER: 0.0
#
# 🔍 test056_1.jpg
#    ✅ Prediksi: N924CIA | GT: N924CIA | CER: 0.0
#
# 🔍 test056_2.jpg
#    ✅ Prediksi: N1623HB | GT: N1623HB | CER: 0.0
#
# 🔍 test056_3.jpg
#    ✅ Prediksi: L1430HF | GT: L1430HF | CER: 0.0
#
# 🔍 test057_1.jpg
#    ✅ Prediksi: N1342T | GT: N1342T | CER: 0.0
#
# 🔍 test057_2.jpg
#    ✅ Prediksi: H4145AB | GT: N4145AB | CER: 0.143
#
# 🔍 test057_3.jpg
#    ✅ Prediksi: N1396AAH | GT: N1396AAH | CER: 0.0
#
# 🔍 test058_1.jpg
#    ✅ Prediksi: N3153ACB | GT: N3153ACB | CER: 0.0
#
# 🔍 test058_2.jpg
#    ✅ Prediksi: 5829KJ | GT: N5829KJ | CER: 0.143
#
# 🔍 test058_3.jpg
#    ✅ Prediksi: N1780JL | GT: N1780JL | CER: 0.0
#
# 🔍 test059_1.jpg
#    ✅ Prediksi: W8774PA | GT: W8774PA | CER: 0.0
#
# 🔍 test059_2.jpg
#    ✅ Prediksi: B9162FXU | GT: B9162FXU | CER: 0.0
#
# 🔍 test060_1.jpg
#    ✅ Prediksi: L1846JE | GT: L1846JE | CER: 0.0
#
# 🔍 test060_2.jpg
#    ✅ Prediksi: M1457ITA | GT: M1457ITA | CER: 0.0
#
# 🔍 test061_1.jpg
#    ✅ Prediksi: AA1971KJ | GT: AA1971KJ | CER: 0.0
#
# 🔍 test061_2.jpg
#    ✅ Prediksi: BD1146DH | GT: BD1146DH | CER: 0.0
#
# 🔍 test062_1.jpg
#    ✅ Prediksi: B9654PEU | GT: B9654PEU | CER: 0.0
#
# 🔍 test062_2.jpg
#    ✅ Prediksi: AE7244S | GT: AE7244S | CER: 0.0
#
# 🔍 test063_1.jpg
#    ✅ Prediksi: S1208BI | GT: S1208BI | CER: 0.0
#
# 🔍 test064_1.jpg
#    ✅ Prediksi: AE8137G | GT: AE8137G | CER: 0.0
#
# 🔍 test065_1.jpg
#    ✅ Prediksi: H1706SW | GT: H1706SW | CER: 0.0
#
# 🔍 test066_1.jpg
#    ✅ Prediksi: HS63 | GT: T1220HS | CER: 1.0
#
# 🔍 test066_2.jpg
#    ✅ Prediksi: H1790ZY | GT: H1790ZY | CER: 0.0
#
# 🔍 test067_1.jpg
#    ✅ Prediksi: 1855BR | GT: L1855BR | CER: 0.143
#
# 🔍 test067_2.jpg
#    ✅ Prediksi: AB1274EV | GT: AB1274EV | CER: 0.0
#
# 🔍 test068_1.jpg
#    ✅ Prediksi: B2310UZS | GT: B2310UZS | CER: 0.0
#
# 🔍 test068_2.jpg
#    ✅ Prediksi: G1264CM | GT: G1264CM | CER: 0.0
#
# 🔍 test069_1.jpg
#    ✅ Prediksi: AA1138AK | GT: AA1138AK | CER: 0.0
#
# 🔍 test070_1.jpg
#    ✅ Prediksi: B2160TOB | GT: B2160TOB | CER: 0.0
#
# 🔍 test070_2.jpg
#    ✅ Prediksi: B2597BYK | GT: B2597BYK | CER: 0.0
#
# 🔍 test071_1.jpg
#    ✅ Prediksi: G9545AG | GT: G9545AG | CER: 0.0
#
# 🔍 test072_1.jpg
#    ✅ Prediksi: BG1870IB | GT: BG1870IB | CER: 0.0
#
# 🔍 test073_1.jpg
#    ✅ Prediksi: 1187HB | GT: T1187HB | CER: 0.143
#
# 🔍 test073_2.jpg
#    ✅ Prediksi: A1330FP | GT: A1330FP | CER: 0.0
#
# 🔍 test074_1.jpg
#    ✅ Prediksi: G1368GE | GT: G1368GE | CER: 0.0
#
# 🔍 test074_2.jpg
#    ✅ Prediksi: B1081CMR | GT: B1081CMR | CER: 0.0
#
# 🔍 test075_1.jpg
#    ✅ Prediksi: G2741Z | GT: G2474XZ | CER: 0.286
#
# 🔍 test075_2.jpg
#    ✅ Prediksi: G9173BP | GT: G9173BP | CER: 0.0
#
# 🔍 test075_3.jpg
#    ✅ Prediksi: 7066JF | GT: 7066OF | CER: 0.167
#
# 🔍 test076_1.jpg
#    ✅ Prediksi: G2151ASF | GT: G2151ASF | CER: 0.0
#
# 🔍 test076_2.jpg
#    ✅ Prediksi: E500MA | GT: E500MA | CER: 0.0
#
# 🔍 test076_3.jpg
#    ✅ Prediksi: SN0126 | GT: G4689SN | CER: 1.0
#
# 🔍 test077_1.jpg
#    ✅ Prediksi: G1754 | GT: G1754QZ | CER: 0.286
#
# 🔍 test078_1.jpg
#    ✅ Prediksi: H1413DH | GT: H1413DH | CER: 0.0
#
# 🔍 test079_1.jpg
#    ✅ Prediksi: T1688GY | GT: T1688GY | CER: 0.0
#
# 🔍 test079_2.jpg
#    ✅ Prediksi: A1260AJ | GT: A1260AJ | CER: 0.0
#
# 🔍 test080_1.jpg
#    ✅ Prediksi: D77HSB | GT: D77HSB | CER: 0.0
#
# 🔍 test080_2.jpg
#    ✅ Prediksi: B1861TAI | GT: B1861TOI | CER: 0.125
#
# 🔍 test080_3.jpg
#    ✅ Prediksi: D1160ADE | GT: D1160ADE | CER: 0.0
#
# 🔍 test081_1.jpg
#    ✅ Prediksi: F8097BD | GT: F8097BD | CER: 0.0
#
# 🔍 test081_2.jpg
#    ✅ Prediksi: F1992AB | GT: F1992AM | CER: 0.143
#
# 🔍 test082_1.jpg
#    ✅ Prediksi: E1824YZ | GT: E1824YZ | CER: 0.0
#
# 🔍 test082_2.jpg
#    ✅ Prediksi: B9093 | GT: B9093UEX | CER: 0.375
#
# 🔍 test083_1.jpg
#    ✅ Prediksi: F5052AAE | GT: F5052AAE | CER: 0.0
#
# 🔍 test083_2.jpg
#    ✅ Prediksi: 5452CO | GT: F5452CQ | CER: 0.286
#
# 🔍 test084_1.jpg
#    ✅ Prediksi: B1158PYP | GT: B1158PYP | CER: 0.0
#
# 🔍 test084_2.jpg
#    ✅ Prediksi: B1242VOY | GT: B1242VOY | CER: 0.0
#
# 🔍 test085_1.jpg
#    ✅ Prediksi: B1315KIF | GT: B1315KIF | CER: 0.0
#
# 🔍 test085_2.jpg
#    ✅ Prediksi: B2938FVJ | GT: B2938FVJ | CER: 0.0
#
# 🔍 test085_3.jpg
#    ✅ Prediksi: B2560SKZ | GT: B2560SKZ | CER: 0.0
#
# 🔍 test086_1.jpg
#    ✅ Prediksi: B1291NOJ | GT: B1291NOJ | CER: 0.0
#
# 🔍 test086_2.jpg
#    ✅ Prediksi: B1556NRC | GT: B1556NRC | CER: 0.0
#
# 🔍 test087_1.jpg
#    ✅ Prediksi: B6823WXR | GT: B6823WXR | CER: 0.0
#
# 🔍 test087_2.jpg
#    ✅ Prediksi: B6317NXX | GT: B6317NXK | CER: 0.125
#
# 🔍 test087_3.jpg
#    ✅ Prediksi: F2215FCO | GT: F2215FCQ | CER: 0.125
#
# 🔍 test087_4.jpg
#    ✅ Prediksi: 4039NHR | GT: 4039NHR | CER: 0.0
#
# 🔍 test088_1.jpg
#    ✅ Prediksi: B2190TYB | GT: B2190TYB | CER: 0.0
#
# 🔍 test088_2.jpg
#    ✅ Prediksi: B1902VKA | GT: B1902VKA | CER: 0.0
#
# 🔍 test089_1.jpg
#    ✅ Prediksi: D8609N | GT: D8609N | CER: 0.0
#
# 🔍 test089_2.jpg
#    ✅ Prediksi: A8406ZE | GT: A8406ZE | CER: 0.0
#
# 🔍 test089_3.jpg
#    ✅ Prediksi: B1246KRK | GT: B1246KRK | CER: 0.0
#
# 🔍 test090_1.jpg
#    ✅ Prediksi: T9314E | GT: T9314E | CER: 0.0
#
# 🔍 test090_2.jpg
#    ✅ Prediksi: N0579U | GT: N9579U | CER: 0.167
#
# 🔍 test091_1.jpg
#    ✅ Prediksi: B2910KZW | GT: B2910KZW | CER: 0.0
#
# 🔍 test091_2.jpg
#    ✅ Prediksi: B9721KXU | GT: B9721KXV | CER: 0.125
#
# 🔍 test092_1.jpg
#    ✅ Prediksi: B1104AAA | GT: B1104AAA | CER: 0.0
#
# 🔍 test092_2.jpg
#    ✅ Prediksi: T1579FN | GT: T1579FN | CER: 0.0
#
# 🔍 test092_3.jpg
#    ✅ Prediksi: B2346POC | GT: B2346POC | CER: 0.0
#
# 🔍 test093_1.jpg
#    ✅ Prediksi: B2026BIU | GT: B2026BIU | CER: 0.0
#
# 🔍 test094_1.jpg
#    ✅ Prediksi: G1255EJ | GT: G1255EJ | CER: 0.0
#
# 🔍 test095_1.jpg
#    ✅ Prediksi: B1201KAD | GT: B1201KAD | CER: 0.0
#
# 🔍 test095_2.jpg
#    ✅ Prediksi: B2310JUK | GT: B2310JUK | CER: 0.0
#
# 🔍 test095_3.jpg
#    ✅ Prediksi: B28YHH | GT: B28YHH | CER: 0.0
#
# 🔍 test096_1.jpg
#    ✅ Prediksi: B1354COJ | GT: B1354COJ | CER: 0.0
#
# 🔍 test096_2.jpg
#    ✅ Prediksi: B1502NRO | GT: B1502NRO | CER: 0.0
#
# 🔍 test097_1.jpg
#    ✅ Prediksi: B1650N | GT: B1650NOG | CER: 0.25
#
# 🔍 test097_2.jpg
#    ✅ Prediksi: B6354SVL | GT: B6354SVL | CER: 0.0
#
# 🔍 test098_1.jpg
#    ✅ Prediksi: B1779DOB | GT: B1779DOB | CER: 0.0
#
# 🔍 test099_1.jpg
#    ✅ Prediksi: B2017PBQ | GT: B2017PBQ | CER: 0.0
#
# 🔍 test099_2.jpg
#    ✅ Prediksi: B1892WZT | GT: B1892WZT | CER: 0.0
#
# 🔍 test100_1.jpg
#    ✅ Prediksi: B1071PRG | GT: B1071PRG | CER: 0.0
#
# 🔍 test100_2.jpg
#    ✅ Prediksi: B2136PZJ | GT: B2134PZJ | CER: 0.125
#
#
# 📊 Rata-rata CER dari 197 gambar: 0.065
